# %%
#1
import pandas

pandas.read_csv("Titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#2
data1 = pandas.read_csv("Titanic.csv", index_col = "PassengerId")
data1
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#3
data1.dropna()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
#4
data1.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...

# %%
#5
data1.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#6
import matplotlib
data1["Age"].hist()
# Out:
# <Axes: >

# %%
#7
data1["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
#8
list(data1.columns)
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
#9
a = list(data1.columns) 
a[1] = "Class"
data1.columns = a
data1
# Out:
#              Survived  Class  \
# PassengerId
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#10
b = data1[data1['Sex'] == 'female']
b
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 9                   1      3
# 10                  1      2
# ...               ...    ...
# 881                 1      2
# 883                 0      3
# 886                 0      3
# 888                 1      1
# 889                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# ...                                                        ...     ...   ...
# ...

# %%
#11
c = data1[(data1['Survived'] == 1) & (data1['Sex'] == 'male') & (data1['Age'] < 32)]
c
# Out:
#              Survived  Class                                             Name  \
# PassengerId
# 24                  1      1                     Sloper, Mr. William Thompson
# 79                  1      2                    Caldwell, Master. Alden Gates
# 82                  1      3                      Sheerlinck, Mr. Jan Baptist
# 98                  1      1                  Greenfield, Mr. William Bertram
# 126                 1      3                     Nicola-Yarred, Master. Elias
# 128                 1      3                        Madsen, Mr. Fridtjof Arne
# 147                 1      3     Andersson, Mr. August Edvard ("Wennerstrom")
# 166                 1      3  Goldsmith, Master. Frank John William "Frankie"
# 184                 1      2                        Becker, Master. Richard F
# 194                 1      2                       Navratil, Master. Michel M
# 205                 1      3                         Cohen, Mr. Gurshon "Gus"
# ...

# %%
#12
d = data1[data1['Class'].isin([1, 2])]
d
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 7                   0      1
# 10                  1      2
# 12                  1      1
# ...               ...    ...
# 881                 1      2
# 884                 0      2
# 887                 0      2
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# ...                                                        ...     ...   ...
# ...

# %%
#13
e = data1[(data1['Survived'] == 1) & (data1['Class'].isin([1, 2]))]
e
# Out:
#              Survived  Class  \
# PassengerId
# 2                   1      1
# 4                   1      1
# 10                  1      2
# 12                  1      1
# 16                  1      2
# ...               ...    ...
# 875                 1      2
# 880                 1      1
# 881                 1      2
# 888                 1      1
# 890                 1      1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...                                                        ...     ...   ...
# ...

# %%
#14
data1["Female"] = ''
data1["Female"] = (data1["Sex"] == "female").astype(int)
data1
# Out:
#              Survived  Class  \
# PassengerId
# 1                   0      3
# 2                   1      1
# 3                   1      3
# 4                   1      1
# 5                   0      3
# ...               ...    ...
# 887                 0      2
# 888                 1      1
# 889                 0      3
# 890                 1      1
# 891                 0      3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#1
print(data1['Embarked'].unique())
# Out:
# ['S' 'C' 'Q' nan]

# %%
#2
data1_survived = data1.select_dtypes(include=['number'])
data1_survived.groupby('Survived').mean()
# Out:
#             Pclass        Age     SibSp     Parch       Fare
# Survived
# 0         2.531876  30.626179  0.553734  0.329690  22.117887
# 1         1.950292  28.343690  0.473684  0.464912  48.395408

# %%
#3
data1_sexage = data1.groupby('Sex')['Age'] .agg(['mean', 'median'])
data1_sexage
# Out:
#              mean  median
# Sex
# female  27.915709    27.0
# male    30.726645    29.0

# %%
#1
data1.columns = data1.columns.str.lower()
data1
# Out:
#              survived  pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
#2
data1.to_csv('Titanic-new.csv', index=False)

# %%
morethan20 = data1[data1['age'] > 20]
died_count = morethan20[morethan20['survived'] == 0].count()
print(died_count["survived"])
survived_count = morethan20[morethan20['survived'] == 1].count()
print(survived_count["survived"])
# Out:
# 327
# 208
