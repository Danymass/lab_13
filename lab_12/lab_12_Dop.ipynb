# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("faults.csv", index_col="X_Minimum")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1941 entries, 42 to 1261
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   X_Maximum              1941 non-null   int64
#  1   Y_Minimum              1941 non-null   int64
#  2   Y_Maximum              1941 non-null   int64
#  3   Pixels_Areas           1941 non-null   int64
#  4   X_Perimeter            1941 non-null   int64
#  5   Y_Perimeter            1941 non-null   int64
#  6   Sum_of_Luminosity      1941 non-null   int64
#  7   Minimum_of_Luminosity  1941 non-null   int64
#  8   Maximum_of_Luminosity  1941 non-null   int64
#  9   Length_of_Conveyer     1941 non-null   int64
#  10  TypeOfSteel_A300       1941 non-null   int64
#  11  TypeOfSteel_A400       1941 non-null   int64
#  12  Steel_Plate_Thickness  1941 non-null   int64
#  13  Edges_Index            1941 non-null   float64
#  14  Empty_Index            1941 non-null   float64
# ...

# %%
df.head()
# Out:
#            X_Maximum  Y_Minimum  Y_Maximum  Pixels_Areas  X_Perimeter  \
# X_Minimum
# 42                50     270900     270944           267           17
# 645              651    2538079    2538108           108           10
# 829              835    1553913    1553931            71            8
# 853              860     369370     369415           176           13
# 1289            1306     498078     498335          2409           60
#
#            Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# X_Minimum
# 42                  44              24220                     76
# 645                 30              11397                     84
# 829                 19               7972                     99
# 853                 45              18996                     99
# 1289               260             246930                     37
#
#            Maximum_of_Luminosity  Length_of_Conveyer  ...  Orientation_Index  \
# ...

# %%
df_nodup.describe()
# Out:
#          X_Maximum     Y_Minimum     Y_Maximum   Pixels_Areas   X_Perimeter  \
# count  1941.000000  1.941000e+03  1.941000e+03    1941.000000   1941.000000
# mean    617.964451  1.650685e+06  1.650739e+06    1893.878413    111.855229
# std     497.627410  1.774578e+06  1.774590e+06    5168.459560    301.209187
# min       4.000000  6.712000e+03  6.724000e+03       2.000000      2.000000
# 25%     192.000000  4.712530e+05  4.712810e+05      84.000000     15.000000
# 50%     467.000000  1.204128e+06  1.204136e+06     174.000000     26.000000
# 75%    1072.000000  2.183073e+06  2.183084e+06     822.000000     84.000000
# max    1713.000000  1.298766e+07  1.298769e+07  152655.000000  10449.000000
#
#         Y_Perimeter  Sum_of_Luminosity  Minimum_of_Luminosity  \
# count   1941.000000       1.941000e+03            1941.000000
# mean      82.965997       2.063121e+05              84.548686
# std      426.482879       5.122936e+05              32.134276
# ...

# %%
histo = df_nodup["X_Maximum"].plot.hist()
histo.set_xlabel("Максимум X")
histo.set_ylabel("Дефекты металлических пластин")
histo.set_title("Steel plate faults")
histo
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Максимум X', ylabel='Дефекты металлических пластин'>

# %%
histo = df_nodup["Y_Maximum"].plot.hist()
histo.set_xlabel("Максимум Y")
histo.set_ylabel("Дефекты металлических пластин")
histo.set_title("Steel plate faults")
histo
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Максимум Y', ylabel='Дефекты металлических пластин'>

# %%
histo = df_nodup["X_Perimeter"].plot.hist()
histo.set_xlabel("Периметр X")
histo.set_ylabel("Дефекты металлических пластин")
histo.set_title("Steel plate faults")
histo
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Периметр X', ylabel='Дефекты металлических пластин'>

# %%
histo = df_nodup["Y_Perimeter"].plot.hist()
histo.set_xlabel("Периметр Y")
histo.set_ylabel("Дефекты металлических пластин")
histo.set_title("Steel plate faults")
histo
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Дефекты металлических пластин', ylabel='Периметр Y'>

# %%
bard = df_nodup['Pixels_Areas'].value_counts().plot.bar()
bard.set_xlabel("Дефектыв определённых местах")
bard.set_ylabel("Дефекты металлических пластин")
bard.set_title("Steel plate faults")
bard
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Дефектыв определённых местах', ylabel='Дефекты металлических пластин'>

# %%
bard = df_nodup['Pastry'].value_counts().plot.bar()
bard.set_xlabel("Дефекты")
bard.set_ylabel("Дефекты металлических пластин")
bard.set_title("Steel plate faults")
bard
# Out:
# <Axes: title={'center': 'Steel plate faults'}, xlabel='Дефекты', ylabel='Дефекты металлических пластин'>
